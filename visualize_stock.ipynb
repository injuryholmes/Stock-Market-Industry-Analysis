# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('./data/L2gold801053.SI/600766.SS.csv', encoding='utf_8_sig')

# %%
train = df[-2000:]

# %%
# gca stands for 'get current axis'
ax = plt.gca()

train.plot(kind='line',x='Date',y='Close', color='red', ax=ax, figsize=(18,16))

plt.show()
